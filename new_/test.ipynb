# %%
from bioesag import BioEsAg as bio_
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import h5py
from simulation import individual_simulation as sim_

# %%
t = np.zeros((100, 100))
t[20:80, 20:80] = .8
sns.heatmap(t)
plt.show()

ind_params = {"species_parameters":[(.36, .12, .6), (.2, .1, .4)],
              "pair_parameters":[(1.6, .3, .1, .17)]}
sim_params = {"max_simulation_epoch":200,
              "simulation_stop_time":20,
              "time_step": .2}

# %%
obj = bio_(target=t, population_size=50, individual_shape=(3, 100, 100), individual_parameters=ind_params,
                 simulation_parameters=sim_params,
                 store_path="/home/samani/Documents/sim/test/hhh/",
                 optimization_epochs=0, evolution_one_epochs=100, evolution_two_epochs=0,
                 learning_rate=0.001, sim_mutation_rate=0.1, compartment_mutation_rate=0.8, parameter_mutation_rate=0.1,
                 insertion_mutation_rate=0.05, deletion_mutation_rate=0.1, crossover_alpha=0.5,
                 checkpoint_interval=5, lr_decay=False, decay_steps=10000, decay_rate=0.98, trainable_compartment=1,
                 gradient_optimization=False, parameter_optimization=False, condition_optimization=False,
                 sim_mutation=True, compartment_mutation=True, param_mutation=True, species_insertion_mutation_one=True,
                 species_deletion_mutation_one=True, species_insertion_mutation_two=False, species_deletion_mutation_two=False,
                 compartment_crossover=True, param_crossover=True, sim_crossover=True,
                 individual_fix_shape=False, cost_alpha=0.6, cost_beta=0.4, cost_max_val=1.0, num_gradient_optimization=1,
                 num_saved_individuals=3, evolution_two_ratio=0.2, zoom_=False, zoom_in_factor=0.5, zoom_out_factor=2,
                 zoom_order=1, zoom_mode="constant", zoom_cval=0.0, zoom_grid_mode=False, num_elite_individuals=5,
                 sim_means=(5.0, 0.5), sim_std_devs=(100.0, 2.0), sim_min_vals=(5.0, 0.1), sim_max_vals=(100.0, 1.0),
                 compartment_mean=0.0, compartment_std=100.0, compartment_min_val=-1.0, compartment_max_val=1.0,
                 species_param_means=(0.0, 0.0, 0.0), species_param_stds=(10.0, 5.0, 10.0), species_param_min_vals=(-1.0, -1.0, -1.0),
                 species_param_max_vals=(1.0, 1.0, 1.0), complex_param_means=(0.0, 0.0, 0.0, 0.0),
                 complex_param_stds=(100.0, 10.0, 5.0, 10.0), complex_param_min_vals=(-1, -1, -1, -1), complex_param_max_vals=(1, 1, 1, 1),
                 param_distribution="uniform",  compartment_distribution="uniform", sim_distribution="uniform")

# %%
model = obj.fit()
# Out:
# --------------------------------------------------------
#                    BioEsAg Algorithm
# --------------------------------------------------------
#               Evolutionary Optimization I
#
# (7, 100, 100)
# Epoch 1/100, Avg/Min Population Cost: 0.38203/0.33536
# there is no elite-individual !!!
# there is no elite-individual !!!
# there is no elite-individual !!!
# (3, 100, 100)
# Epoch 2/100, Avg/Min Population Cost: 0.45267/0.33535
# (7, 100, 100)
# Epoch 3/100, Avg/Min Population Cost: 0.40803/0.33535
# (7, 100, 100)
# Epoch 4/100, Avg/Min Population Cost: 0.54865/0.3354
# (7, 100, 100)
# Epoch 5/100, Avg/Min Population Cost: 0.49215/0.45564
# (7, 100, 100)
# Epoch 6/100, Avg/Min Population Cost: 0.47665/0.45003
# (7, 100, 100)
# Epoch 7/100, Avg/Min Population Cost: 0.4701/0.34102
# (7, 100, 100)
# Epoch 8/100, Avg/Min Population Cost: 0.46949/0.33546
# (13, 100, 100)
# Epoch 9/100, Avg/Min Population Cost: 0.50273/0.33546
# (13, 100, 100)
# Epoch 10/100, Avg/Min Population Cost: 0.4971/0.33538
# (13, 100, 100)
# Epoch 11/100, Avg/Min Population Cost: 0.64136/0.33538
# (13, 100, 100)
# Epoch 12/100, Avg/Min Population Cost: 0.84213/0.39709
# (13, 100, 100)
# Epoch 13/100, Avg/Min Population Cost: 2.704902468100616e+94/0.39352
# (13, 100, 100)
# Epoch 14/100, Avg/Min Population Cost: 0.49058/0.44385
# there is no elite-individual !!!
# there is no elite-individual !!!
# (7, 100, 100)
# Epoch 15/100, Avg/Min Population Cost: 0.47305/0.35091
# (7, 100, 100)
# Epoch 16/100, Avg/Min Population Cost: 0.46068/0.34202
# (7, 100, 100)
# Epoch 17/100, Avg/Min Population Cost: 0.45841/0.33579
# (7, 100, 100)
# Epoch 18/100, Avg/Min Population Cost: 0.43871/0.33535
# there is no elite-individual !!!
# there is no elite-individual !!!
# (3, 100, 100)
# Epoch 19/100, Avg/Min Population Cost: 0.4167/0.33535
# /home/samani/Documents/projects/venv/lib/python3.10/site-packages/skimage/metrics/_structural_similarity.py:268: RuntimeWarning: overflow encountered in multiply
#   D = B1 * B2
# (7, 100, 100)
# Epoch 20/100, Avg/Min Population Cost: 5.671033497613024e+156/0.33535
# (7, 100, 100)
# Epoch 21/100, Avg/Min Population Cost: 0.48289/0.45225
# (7, 100, 100)
# Epoch 22/100, Avg/Min Population Cost: 0.47132/0.35072
# (7, 100, 100)
# Epoch 23/100, Avg/Min Population Cost: 0.46964/0.33579
# (7, 100, 100)
# Epoch 24/100, Avg/Min Population Cost: 0.51935/0.33579
# (13, 100, 100)
# Epoch 25/100, Avg/Min Population Cost: 0.53821/0.45531
# (21, 100, 100)
# Epoch 26/100, Avg/Min Population Cost: 0.55394/0.33612
# (21, 100, 100)
# Epoch 27/100, Avg/Min Population Cost: 1.03437/0.33678
# (21, 100, 100)
# Epoch 28/100, Avg/Min Population Cost: 0.52034/0.45389
# (21, 100, 100)
# Epoch 29/100, Avg/Min Population Cost: 0.4906/0.45389
# (21, 100, 100)
# Epoch 30/100, Avg/Min Population Cost: 0.49472/0.45524
# (21, 100, 100)
# Epoch 31/100, Avg/Min Population Cost: 0.51632/0.45544
# (21, 100, 100)
# Epoch 32/100, Avg/Min Population Cost: 0.57433/0.45558
# (21, 100, 100)
# Epoch 33/100, Avg/Min Population Cost: 1.1399/0.4536
# (21, 100, 100)
# Epoch 34/100, Avg/Min Population Cost: 6.648839671416786e+55/0.45723
# (21, 100, 100)
# Epoch 35/100, Avg/Min Population Cost: 0.72412/0.45017
# (21, 100, 100)
# Epoch 36/100, Avg/Min Population Cost: 0.49483/0.33539
# there is no elite-individual !!!
# (21, 100, 100)
# Epoch 37/100, Avg/Min Population Cost: 0.46975/0.33536
# there is no elite-individual !!!
# (13, 100, 100)
# Epoch 38/100, Avg/Min Population Cost: 0.46223/0.33536
# (13, 100, 100)
# Epoch 39/100, Avg/Min Population Cost: 2.19782/0.34227
# (13, 100, 100)
# Epoch 40/100, Avg/Min Population Cost: 0.52911/0.45419
# (7, 100, 100)
# Epoch 41/100, Avg/Min Population Cost: 0.5338/0.33686
# (7, 100, 100)
# Epoch 42/100, Avg/Min Population Cost: 146226287130.9749/0.33686
# (13, 100, 100)
# Epoch 43/100, Avg/Min Population Cost: 0.49107/0.33541
# (13, 100, 100)
# Epoch 44/100, Avg/Min Population Cost: 0.47193/0.33541
# (13, 100, 100)
# Epoch 45/100, Avg/Min Population Cost: 0.48275/0.33541
# (21, 100, 100)
# Epoch 46/100, Avg/Min Population Cost: 1.6073943421979977e+54/0.33541
# (21, 100, 100)
# Epoch 47/100, Avg/Min Population Cost: 0.57392/0.33541
# there is no elite-individual !!!
# (21, 100, 100)
# Epoch 48/100, Avg/Min Population Cost: 0.53714/0.33541
# (21, 100, 100)
# Epoch 49/100, Avg/Min Population Cost: 2.22585/0.33541
# (21, 100, 100)
# Epoch 50/100, Avg/Min Population Cost: 0.48686/0.33541
# (13, 100, 100)
# Epoch 51/100, Avg/Min Population Cost: 0.62608/0.33541
# (13, 100, 100)
# Epoch 52/100, Avg/Min Population Cost: 2.3285562307347592e+69/0.33541
# (21, 100, 100)
# Epoch 53/100, Avg/Min Population Cost: 0.51182/0.33541
# (21, 100, 100)
# Epoch 54/100, Avg/Min Population Cost: 0.50084/0.33541
# (21, 100, 100)
# Epoch 55/100, Avg/Min Population Cost: 7.373114315503577e+161/0.33541
# (21, 100, 100)
# Epoch 56/100, Avg/Min Population Cost: 64495201330261.68/0.45444
# (13, 100, 100)
# Epoch 57/100, Avg/Min Population Cost: 0.49795/0.33766
# (13, 100, 100)
# Epoch 58/100, Avg/Min Population Cost: 0.47189/0.33739
# (13, 100, 100)
# Epoch 59/100, Avg/Min Population Cost: 0.464/0.33739
# there is no elite-individual !!!
# (21, 100, 100)
# Epoch 60/100, Avg/Min Population Cost: 0.4595/0.33536
# there is no elite-individual !!!
# (13, 100, 100)
# Epoch 61/100, Avg/Min Population Cost: 0.45432/0.33536
# there is no elite-individual !!!
# there is no elite-individual !!!
# there is no elite-individual !!!
# there is no elite-individual !!!
# there is no elite-individual !!!
# there is no elite-individual !!!
# there is no elite-individual !!!
# there is no elite-individual !!!
# (3, 100, 100)
# Epoch 62/100, Avg/Min Population Cost: 0.43491/0.33539
# (7, 100, 100)
# Epoch 63/100, Avg/Min Population Cost: 0.41046/0.33536
# there is no elite-individual !!!
# (3, 100, 100)
# Epoch 64/100, Avg/Min Population Cost: 0.43971/0.33535
# (7, 100, 100)
# Epoch 65/100, Avg/Min Population Cost: 0.41418/0.33535
# (7, 100, 100)
# Epoch 66/100, Avg/Min Population Cost: 0.43007/0.33535
# there is no elite-individual !!!
# (3, 100, 100)
# Epoch 67/100, Avg/Min Population Cost: 0.42217/0.33538
# (3, 100, 100)
# Epoch 68/100, Avg/Min Population Cost: 0.43147/0.33538
# (3, 100, 100)
# Epoch 69/100, Avg/Min Population Cost: 0.43752/0.33535
# (3, 100, 100)
# Epoch 70/100, Avg/Min Population Cost: 0.43683/0.33535
# (3, 100, 100)
# Epoch 71/100, Avg/Min Population Cost: 0.41616/0.33535
# (3, 100, 100)
# Epoch 72/100, Avg/Min Population Cost: 0.43881/0.33535
# (7, 100, 100)
# Epoch 73/100, Avg/Min Population Cost: 0.42483/0.33535
# (7, 100, 100)
# Epoch 74/100, Avg/Min Population Cost: 0.43653/0.33535
# (7, 100, 100)
# Epoch 75/100, Avg/Min Population Cost: 0.41203/0.33535
# (7, 100, 100)
# Epoch 76/100, Avg/Min Population Cost: 0.43695/0.33536
# (7, 100, 100)
# Epoch 77/100, Avg/Min Population Cost: 0.43668/0.33537
# (7, 100, 100)
# Epoch 78/100, Avg/Min Population Cost: 0.42848/0.33535
# (7, 100, 100)
# Epoch 79/100, Avg/Min Population Cost: 0.43236/0.33535
# (7, 100, 100)
# Epoch 80/100, Avg/Min Population Cost: 0.4264/0.33536
# (7, 100, 100)
# Epoch 81/100, Avg/Min Population Cost: 0.41685/0.33538
# (7, 100, 100)
# Epoch 82/100, Avg/Min Population Cost: 0.44516/0.33537
# there is no elite-individual !!!
# (3, 100, 100)
# Epoch 83/100, Avg/Min Population Cost: 0.42952/0.33537
# (3, 100, 100)
# Epoch 84/100, Avg/Min Population Cost: 0.43075/0.33541
# (3, 100, 100)
# Epoch 85/100, Avg/Min Population Cost: 0.42952/0.33541
# (7, 100, 100)
# Epoch 86/100, Avg/Min Population Cost: 0.43865/0.33562
# (7, 100, 100)
# Epoch 87/100, Avg/Min Population Cost: 0.42456/0.33537
# there is no elite-individual !!!
# (3, 100, 100)
# Epoch 88/100, Avg/Min Population Cost: 0.43193/0.33535
# (7, 100, 100)
# Epoch 89/100, Avg/Min Population Cost: 0.43314/0.33535
# (7, 100, 100)
# Epoch 90/100, Avg/Min Population Cost: 0.4195/0.33535
# (7, 100, 100)
# Epoch 91/100, Avg/Min Population Cost: 0.43229/0.33538
# (7, 100, 100)
# Epoch 92/100, Avg/Min Population Cost: 0.43649/0.33538
# (7, 100, 100)
# Epoch 93/100, Avg/Min Population Cost: 0.42816/0.33538
# there is no elite-individual !!!
# (3, 100, 100)
# Epoch 94/100, Avg/Min Population Cost: 0.44949/0.33535
# (3, 100, 100)
# Epoch 95/100, Avg/Min Population Cost: 0.41462/0.33535
# (3, 100, 100)
# Epoch 96/100, Avg/Min Population Cost: 0.43914/0.33546
# (3, 100, 100)
# Epoch 97/100, Avg/Min Population Cost: 0.42526/0.33535
# (7, 100, 100)
# Epoch 98/100, Avg/Min Population Cost: 0.44224/0.33535
# there is no elite-individual !!!
# there is no elite-individual !!!
# (3, 100, 100)
# Epoch 99/100, Avg/Min Population Cost: 0.42146/0.33537
# (7, 100, 100)
# Epoch 100/100, Avg/Min Population Cost: 0.43359/0.33539

# %%
del obj
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 del obj
#
# NameError: name 'obj' is not defined

# %%
data = h5py.File("/home/samani/Documents/sim/test/output_data.h5")

# %%
print(data.keys())
# Out:
# <KeysViewHDF5 ['elite_individual_1_evolution_one', 'elite_individual_2_evolution_one', 'elite_individual_3_evolution_one', 'evolution_costs_one', 'evolution_one_results', 'original_target', 'run_time', 'zoomed_in_target']>

# %%
ind1 = data["elite_individual_3_evolution_one"][:]
print(ind1.shape)
# Out:
# (3, 100, 100)

# %%
cost = data['evolution_costs_one'][:]
print(cost.shape)
# Out:
# (100, 5)

# %%
res_ = data['evolution_one_results'][:]
print(res_.shape)
# Out:
# (100, 100, 100)

# %%
sns.heatmap(res_[30, :, :])
# Out:
# <Axes: >

# %%
t = data['original_target']
sns.heatmap(t)
# Out:
# <Axes: >

# %%
r = data['run_time'][:]
print(r)
# Out:
# [6.19969368e-02 3.95927950e+03 0.00000000e+00 4.76837158e-07]

# %%
def generate_complex_infinity_pattern(matrix_size=100, start_col=20, end_col=80, base_thickness=5, amplitude=5, frequency=5):
    # Create an empty matrix
    matrix = np.zeros((matrix_size, matrix_size))

    # Parametric equations for the infinity symbol (lemniscate of Bernoulli)
    t = np.linspace(0, 2 * np.pi, 1000)  # Parameter from 0 to 2pi

    # Infinity symbol parametric equations
    x = np.sin(t) / (1 + np.cos(t) ** 2)
    y = np.sin(t) * np.cos(t) / (1 + np.cos(t) ** 2)

    # Sinusoidal modulation for y-coordinates (adds complexity)
    y_modulation = amplitude * np.sin(frequency * t)
    y += y_modulation

    # Normalize x and y to fit the matrix dimensions and the required column range
    x_norm = np.interp(x, (x.min(), x.max()), (start_col, end_col))  # Normalize x from start to end col
    y_norm = np.interp(y, (y.min(), y.max()), (20, 80))  # Normalize y to stay within the central region of matrix

    # Plot the points on the matrix with varying thickness along the curve
    for i in range(len(t)):
        x_pos = int(x_norm[i])
        y_pos = int(y_norm[i])

        # Thickness modulation (varies thickness along the curve)
        thickness = int(base_thickness + 3 * np.sin(2 * np.pi * i / len(t)))

        # Ensure the thickness by drawing a small square around the current point
        matrix[max(0, y_pos-thickness//2):min(matrix_size, y_pos+thickness//2),
               max(0, x_pos-thickness//2):min(matrix_size, x_pos+thickness//2)] = 1

    return matrix

# %%
# Generate the complex pattern
t = generate_complex_infinity_pattern()

# Plot the matrix to visualize the more complex infinity symbol
plt.imshow(t)
plt.show()

# %%
ind = np.zeros((3, 100, 100))
ind[1, :, :] = t
ind[-1, 0, :3] = (1, .1, .9)
ind[-1, -1, :5] = (1, 0, 1000, 50, .2)
tt = sim_(ind)

# %%
sns.heatmap(tt)
# Out:
# <Axes: >

# %%
ind_params = {"species_parameters":[(1, .1, .9)],
              "pair_parameters":[(1.6, .3, .1, .17)]}
sim_params = {"max_simulation_epoch":1000,
              "simulation_stop_time":50,
              "time_step": .2}

# %%
obj = bio_(target=tt, population_size=100, individual_shape=(3, 100, 100), individual_parameters=ind_params,
                 simulation_parameters=sim_params,
                 store_path="/home/samani/Documents/sim/test/hhh/",
                 optimization_epochs=0, evolution_one_epochs=100, evolution_two_epochs=0,
                 learning_rate=0.001, sim_mutation_rate=0.1, compartment_mutation_rate=0.8, parameter_mutation_rate=0.1,
                 insertion_mutation_rate=0.04, deletion_mutation_rate=0.6, crossover_alpha=0.5,
                 checkpoint_interval=5, lr_decay=False, decay_steps=10000, decay_rate=0.98, trainable_compartment=1,
                 gradient_optimization=False, parameter_optimization=False, condition_optimization=False,
                 sim_mutation=True, compartment_mutation=True, param_mutation=True, species_insertion_mutation_one=True,
                 species_deletion_mutation_one=True, species_insertion_mutation_two=False, species_deletion_mutation_two=False,
                 compartment_crossover=True, param_crossover=True, sim_crossover=True,
                 individual_fix_shape=False, cost_alpha=0.6, cost_beta=0.4, cost_max_val=1.0, num_gradient_optimization=1,
                 num_saved_individuals=100, evolution_two_ratio=1, zoom_=False, zoom_in_factor=0.5, zoom_out_factor=2,
                 zoom_order=1, zoom_mode="constant", zoom_cval=0.0, zoom_grid_mode=False, num_elite_individuals=5,
                 sim_means=(5.0, 0.5), sim_std_devs=(100.0, 2.0), sim_min_vals=(5.0, 0.1), sim_max_vals=(100.0, 1.0),
                 compartment_mean=0.0, compartment_std=100.0, compartment_min_val=-1.0, compartment_max_val=1.0,
                 species_param_means=(0.0, 0.0, 0.0), species_param_stds=(10.0, 5.0, 10.0), species_param_min_vals=(-1.0, -1.0, -1.0),
                 species_param_max_vals=(1.0, 1.0, 1.0), complex_param_means=(0.0, 0.0, 0.0, 0.0),
                 complex_param_stds=(100.0, 10.0, 5.0, 10.0), complex_param_min_vals=(-1, -1, -1, -1), complex_param_max_vals=(1, 1, 1, 1),
                 param_distribution="uniform",  compartment_distribution="uniform", sim_distribution="uniform")

# %%
model = obj.fit()
# Out:
# --------------------------------------------------------
#                    BioEsAg Algorithm
# --------------------------------------------------------
#               Evolutionary Optimization I
#
# (7, 100, 100)
# 100
# Epoch 1/100, Avg/Min Population Cost: 4.00256/3.6458
# (7, 100, 100)
# 100
# Epoch 2/100, Avg/Min Population Cost: 3.73365/2.84289
# (7, 100, 100)
# 100
# Epoch 3/100, Avg/Min Population Cost: 3.55827/2.98294
# (7, 100, 100)
# 100
# Epoch 4/100, Avg/Min Population Cost: 3.41847/2.89298
# (7, 100, 100)
# 100
# Epoch 5/100, Avg/Min Population Cost: 3.61174/2.78213
# (7, 100, 100)
# 100
# Epoch 6/100, Avg/Min Population Cost: 3.51635/2.79753
# (3, 100, 100)
# 100
# Epoch 7/100, Avg/Min Population Cost: 3.45298/2.78788
# (7, 100, 100)
# 100
# Epoch 8/100, Avg/Min Population Cost: 3.39824/2.77519
# (3, 100, 100)
# 100
# Epoch 9/100, Avg/Min Population Cost: 3.68464/2.77519
# (7, 100, 100)
# 100
# Epoch 10/100, Avg/Min Population Cost: 4.44983/2.85671
# there is no elite-individual !!!
# (3, 100, 100)
# 100
# Epoch 11/100, Avg/Min Population Cost: 3.41082/2.77796
# (7, 100, 100)
# 100
# Epoch 12/100, Avg/Min Population Cost: 3.4797/2.75168
# there is no elite-individual !!!
# (3, 100, 100)
# 100
# Epoch 13/100, Avg/Min Population Cost: 3.38898/2.75168
# (3, 100, 100)
# 100
# Epoch 14/100, Avg/Min Population Cost: 3.41266/2.95864
# (3, 100, 100)
# 100
# Epoch 15/100, Avg/Min Population Cost: 3.42489/2.84331
# (3, 100, 100)
# 100
# Epoch 16/100, Avg/Min Population Cost: 3.38202/2.92969
# (3, 100, 100)
# 100
# Epoch 17/100, Avg/Min Population Cost: 3.47627/2.85229
# (3, 100, 100)
# 100
# Epoch 18/100, Avg/Min Population Cost: 3.47538/2.80483
# (7, 100, 100)
# 100
# Epoch 19/100, Avg/Min Population Cost: 3.4593/2.80675
# there is no elite-individual !!!
# (3, 100, 100)
# 100
# Epoch 20/100, Avg/Min Population Cost: 3.49089/2.82838
# (3, 100, 100)
# 100
# Epoch 21/100, Avg/Min Population Cost: 3.4646/2.81905
# (3, 100, 100)
# 100
# Epoch 22/100, Avg/Min Population Cost: 3.48597/2.82087
# (7, 100, 100)
# 100
# Epoch 23/100, Avg/Min Population Cost: 3.47784/2.81886
# (7, 100, 100)
# 100
# Epoch 24/100, Avg/Min Population Cost: 4.80473/2.91119
# (7, 100, 100)
# 100
# Epoch 25/100, Avg/Min Population Cost: 1.8263618151224223e+104/2.88992
# (7, 100, 100)
# 100
# Epoch 26/100, Avg/Min Population Cost: 2.5837269942028757e+23/2.97085
# (7, 100, 100)
# 100
# Epoch 27/100, Avg/Min Population Cost: 44511.03729/2.93878
# (7, 100, 100)
# 100
# Epoch 28/100, Avg/Min Population Cost: 3.4239/2.85119
# (7, 100, 100)
# 100
# Epoch 29/100, Avg/Min Population Cost: 2.8856701092836084e+39/2.89483
# (7, 100, 100)
# 100
# Epoch 30/100, Avg/Min Population Cost: 3.57567/2.77365
# (7, 100, 100)
# 100
# Epoch 31/100, Avg/Min Population Cost: 7.00838/2.77365
# (7, 100, 100)
# 100
# Epoch 32/100, Avg/Min Population Cost: 1.2955977520850698e+71/2.88043
# (7, 100, 100)
# 100
# Epoch 33/100, Avg/Min Population Cost: 1.7763413926930535e+101/2.79501
# (7, 100, 100)
# 100
# Epoch 34/100, Avg/Min Population Cost: 9.43054708904433e+195/2.82082
# (7, 100, 100)
# 100
# Epoch 35/100, Avg/Min Population Cost: 1.1188763913692299e+47/2.80088
# (7, 100, 100)
# 100
# Epoch 36/100, Avg/Min Population Cost: 3.75133/2.86988
# there is no elite-individual !!!
# there is no elite-individual !!!
# there is no elite-individual !!!
# (3, 100, 100)
# 100
# Epoch 37/100, Avg/Min Population Cost: 3.38084/2.7847
# (3, 100, 100)
# 100
# Epoch 38/100, Avg/Min Population Cost: 3.29722/2.81152
# (7, 100, 100)
# 100
# Epoch 39/100, Avg/Min Population Cost: 1.208446279280953e+39/2.81152
# (7, 100, 100)
# 100
# Epoch 40/100, Avg/Min Population Cost: 6.71955/2.79812
# (7, 100, 100)
# 100
# Epoch 41/100, Avg/Min Population Cost: 3.39567/2.79812
# (3, 100, 100)
# 100
# Epoch 42/100, Avg/Min Population Cost: 3.43081/2.81711
# (7, 100, 100)
# 100
# Epoch 43/100, Avg/Min Population Cost: 3.43133/2.85202
# (7, 100, 100)
# 100
# Epoch 44/100, Avg/Min Population Cost: 3.48883/2.79011
# (7, 100, 100)
# 100
# Epoch 45/100, Avg/Min Population Cost: 2.5989276170159097e+42/2.79011
# (7, 100, 100)
# 100
# Epoch 46/100, Avg/Min Population Cost: 2.2797647107366153e+203/2.77271
# (3, 100, 100)
# 100
# Epoch 47/100, Avg/Min Population Cost: 2.7959047118644082e+29/2.85722
# (7, 100, 100)
# 100
# Epoch 48/100, Avg/Min Population Cost: 1.6297464142018982e+39/2.82302
# (7, 100, 100)
# 100
# Epoch 49/100, Avg/Min Population Cost: 3.42604/2.77854
# there is no elite-individual !!!
# (3, 100, 100)
# 100
# Epoch 50/100, Avg/Min Population Cost: 3.3452/2.77854
# (3, 100, 100)
# 100
# Epoch 51/100, Avg/Min Population Cost: 3.37861/2.85022
# (3, 100, 100)
# 100
# Epoch 52/100, Avg/Min Population Cost: 3.3798/2.80812
# (3, 100, 100)
# 100
# Epoch 53/100, Avg/Min Population Cost: 3.34422/2.8012
# (7, 100, 100)
# 100
# Epoch 54/100, Avg/Min Population Cost: 3.42007/2.75374
# (7, 100, 100)
# 100
# Epoch 55/100, Avg/Min Population Cost: 5.40991/2.78512
# (7, 100, 100)
# 100
# Epoch 56/100, Avg/Min Population Cost: 3.59904/2.82582
# (7, 100, 100)
# 100
# Epoch 57/100, Avg/Min Population Cost: 3.47521/2.82582
# there is no elite-individual !!!
# (7, 100, 100)
# 100
# Epoch 58/100, Avg/Min Population Cost: 3.38331/2.78029
# (7, 100, 100)
# 100
# Epoch 59/100, Avg/Min Population Cost: 3.47156/2.78029
# (7, 100, 100)
# 100
# Epoch 60/100, Avg/Min Population Cost: 45.0735/2.81219
# (7, 100, 100)
# 100
# Epoch 61/100, Avg/Min Population Cost: 6.490700878231885e+172/2.8038
# (7, 100, 100)
# 100
# Epoch 62/100, Avg/Min Population Cost: 3.44201/2.79934
# (7, 100, 100)
# 100
# Epoch 63/100, Avg/Min Population Cost: 3.62338/2.79582
# (7, 100, 100)
# 100
# Epoch 64/100, Avg/Min Population Cost: 3.72013/2.79582
# (7, 100, 100)
# 100
# Epoch 65/100, Avg/Min Population Cost: 1016859774968139.6/2.80563
# (7, 100, 100)
# 100
# Epoch 66/100, Avg/Min Population Cost: 8.662710505202218e+115/2.95025
# (3, 100, 100)
# 100
# Epoch 67/100, Avg/Min Population Cost: 3.41551/2.80201
# (7, 100, 100)
# 100
# Epoch 68/100, Avg/Min Population Cost: 3.40378/2.8482
# (7, 100, 100)
# 100
# Epoch 69/100, Avg/Min Population Cost: 3.64851/2.80432
# (7, 100, 100)
# 100
# Epoch 70/100, Avg/Min Population Cost: 3.32082/2.80432
# (7, 100, 100)
# 100
# Epoch 71/100, Avg/Min Population Cost: 1.6909327350457404e+39/2.78273
# there is no elite-individual !!!
# (3, 100, 100)
# 100
# Epoch 72/100, Avg/Min Population Cost: 3.44661/2.81612
# (7, 100, 100)
# 100
# Epoch 73/100, Avg/Min Population Cost: 3.49942/2.86555
# (7, 100, 100)
# 100
# Epoch 74/100, Avg/Min Population Cost: 4.0203/2.76146
# (7, 100, 100)
# 100
# Epoch 75/100, Avg/Min Population Cost: 4.598697452675578e+44/2.76146
# (3, 100, 100)
# 100
# Epoch 76/100, Avg/Min Population Cost: 6.0443081749816474e+38/2.99296
# (3, 100, 100)
# 100
# Epoch 77/100, Avg/Min Population Cost: 3.42032/2.81015
# (7, 100, 100)
# 100
# Epoch 78/100, Avg/Min Population Cost: 3.57488/2.78155
# (7, 100, 100)
# 100
# Epoch 79/100, Avg/Min Population Cost: 3.4627/2.78155
# (7, 100, 100)
# 100
# Epoch 80/100, Avg/Min Population Cost: 8.401876995673436e+99/2.85126
# (7, 100, 100)
# 100
# Epoch 81/100, Avg/Min Population Cost: 3.40857/2.84451
# (7, 100, 100)
# 100
# Epoch 82/100, Avg/Min Population Cost: 3.43755/2.87542
# (7, 100, 100)
# 100
# Epoch 83/100, Avg/Min Population Cost: 4.60731/2.81624
# (7, 100, 100)
# 100
# Epoch 84/100, Avg/Min Population Cost: 4.0934460076445233e+21/2.80857
# (7, 100, 100)
# 100
# Epoch 85/100, Avg/Min Population Cost: 5.165355440499846e+148/2.77908
# (7, 100, 100)
# 100
# Epoch 86/100, Avg/Min Population Cost: 3.130946171135903e+136/2.7578
# (7, 100, 100)
# 100
# Epoch 87/100, Avg/Min Population Cost: 1.7787120008348797e+19/2.90265
# (7, 100, 100)
# 100
# Epoch 88/100, Avg/Min Population Cost: 1.9264863598191184e+245/2.81134
# (7, 100, 100)
# 100
# Epoch 89/100, Avg/Min Population Cost: 1.595370995741278e+233/2.82648
# (7, 100, 100)
# 100
# Epoch 90/100, Avg/Min Population Cost: 6.3486/2.77096
# (7, 100, 100)
# 100
# Epoch 91/100, Avg/Min Population Cost: 2.1686373790886095e+286/2.77096
# (7, 100, 100)
# 100
# Epoch 92/100, Avg/Min Population Cost: 3.88372/2.77297
# (7, 100, 100)
# 100
# Epoch 93/100, Avg/Min Population Cost: 12969790.97367/2.76208
# there is no elite-individual !!!
# there is no elite-individual !!!
# (3, 100, 100)
# 100
# Epoch 94/100, Avg/Min Population Cost: 3.44312/2.77138
# (7, 100, 100)
# 100
# Epoch 95/100, Avg/Min Population Cost: 3.41056/2.78745
# (7, 100, 100)
# 100
# Epoch 96/100, Avg/Min Population Cost: 1641101157514840.0/2.88199
# /home/samani/Documents/projects/venv/lib/python3.10/site-packages/skimage/metrics/_structural_similarity.py:253: RuntimeWarning: overflow encountered in multiply
#   uxy = filter_func(im1 * im2, **filter_args)
# /home/samani/Documents/projects/venv/lib/python3.10/site-packages/skimage/metrics/_structural_similarity.py:256: RuntimeWarning: invalid value encountered in subtract
#   vxy = cov_norm * (uxy - ux * uy)
# there is no elite-individual !!!
# (3, 100, 100)
# 100
# Epoch 97/100, Avg/Min Population Cost: 3.38367/2.90365
# (7, 100, 100)
# 100
# Epoch 98/100, Avg/Min Population Cost: 3.40894/2.89292
# (7, 100, 100)
# 100
# Epoch 99/100, Avg/Min Population Cost: 3.45408/2.78799
# (7, 100, 100)
# 100
# Epoch 100/100, Avg/Min Population Cost: 3.46341/2.7544

# %%
del obj
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 del obj
#
# NameError: name 'obj' is not defined

# %%
data = h5py.File("/home/samani/Documents/sim/test/hhh/output_data.h5")
data.close()

# %%
print(data.keys())
# Out:
# <KeysViewHDF5 ['elite_individual_100_evolution_one', 'elite_individual_10_evolution_one', 'elite_individual_11_evolution_one', 'elite_individual_12_evolution_one', 'elite_individual_13_evolution_one', 'elite_individual_14_evolution_one', 'elite_individual_15_evolution_one', 'elite_individual_16_evolution_one', 'elite_individual_17_evolution_one', 'elite_individual_18_evolution_one', 'elite_individual_19_evolution_one', 'elite_individual_1_evolution_one', 'elite_individual_20_evolution_one', 'elite_individual_21_evolution_one', 'elite_individual_22_evolution_one', 'elite_individual_23_evolution_one', 'elite_individual_24_evolution_one', 'elite_individual_25_evolution_one', 'elite_individual_26_evolution_one', 'elite_individual_27_evolution_one', 'elite_individual_28_evolution_one', 'elite_individual_29_evolution_one', 'elite_individual_2_evolution_one', 'elite_individual_30_evolution_one', 'elite_individual_31_evolution_one', 'elite_individual_32_evolution_one', 'elite_individual_33_evolution_one', 'elite_individual_34_evolution_one', 'elite_individual_35_evolution_one', 'elite_individual_36_evolution_one', 'elite_individual_37_evolution_one', 'elite_individual_38_evolution_one', 'elite_individual_39_evolution_one', 'elite_individual_3_evolution_one', 'elite_individual_40_evolution_one', 'elite_individual_41_evolution_one', 'elite_individual_42_evolution_one', 'elite_individual_43_evolution_one', 'elite_individual_44_evolution_one', 'elite_individual_45_evolution_one', 'elite_individual_46_evolution_one', 'elite_individual_47_evolution_one', 'elite_individual_48_evolution_one', 'elite_individual_49_evolution_one', 'elite_individual_4_evolution_one', 'elite_individual_50_evolution_one', 'elite_individual_51_evolution_one', 'elite_individual_52_evolution_one', 'elite_individual_53_evolution_one', 'elite_individual_54_evolution_one', 'elite_individual_55_evolution_one', 'elite_individual_56_evolution_one', 'elite_individual_57_evolution_one', 'elite_individual_58_evolution_one', 'elite_individual_59_evolution_one', 'elite_individual_5_evolution_one', 'elite_individual_60_evolution_one', 'elite_individual_61_evolution_one', 'elite_individual_62_evolution_one', 'elite_individual_63_evolution_one', 'elite_individual_64_evolution_one', 'elite_individual_65_evolution_one', 'elite_individual_66_evolution_one', 'elite_individual_67_evolution_one', 'elite_individual_68_evolution_one', 'elite_individual_69_evolution_one', 'elite_individual_6_evolution_one', 'elite_individual_70_evolution_one', 'elite_individual_71_evolution_one', 'elite_individual_72_evolution_one', 'elite_individual_73_evolution_one', 'elite_individual_74_evolution_one', 'elite_individual_75_evolution_one', 'elite_individual_76_evolution_one', 'elite_individual_77_evolution_one', 'elite_individual_78_evolution_one', 'elite_individual_79_evolution_one', 'elite_individual_7_evolution_one', 'elite_individual_80_evolution_one', 'elite_individual_81_evolution_one', 'elite_individual_82_evolution_one', 'elite_individual_83_evolution_one', 'elite_individual_84_evolution_one', 'elite_individual_85_evolution_one', 'elite_individual_86_evolution_one', 'elite_individual_87_evolution_one', 'elite_individual_88_evolution_one', 'elite_individual_89_evolution_one', 'elite_individual_8_evolution_one', 'elite_individual_90_evolution_one', 'elite_individual_91_evolution_one', 'elite_individual_92_evolution_one', 'elite_individual_93_evolution_one', 'elite_individual_94_evolution_one', 'elite_individual_95_evolution_one', 'elite_individual_96_evolution_one', 'elite_individual_97_evolution_one', 'elite_individual_98_evolution_one', 'elite_individual_99_evolution_one', 'elite_individual_9_evolution_one', 'evolution_costs_one', 'original_target', 'run_time', 'zoomed_in_target']>

# %%
f = []
for i in range(1, 101):
    if data[f'elite_individual_{i}_evolution_one'].shape[0] > 3:
        f.append(data[f'elite_individual_{i}_evolution_one'])
print(f)
# Out:
# [<HDF5 dataset "elite_individual_9_evolution_one": shape (7, 100, 100), type "<f8">, <HDF5 dataset "elite_individual_27_evolution_one": shape (7, 100, 100), type "<f8">, <HDF5 dataset "elite_individual_49_evolution_one": shape (7, 100, 100), type "<f8">]

# %%
el = f[2]
print(el[-1, 0, :3])
print(el[-1, 2, :3])
print(el[-2, 0, :2])
print(el[-2, 1, :4])
print(el[-1, -1, :5])
# Out:
# [0.91937637 0.6301695  0.82292209]
# [0.53601272 0.11356867 0.22559909]
# [0. 2.]
# [0.17838581 0.52900741 0.10278303 0.16141692]
# [2.0000000e+00 1.0000000e+00 1.0000000e+03 4.5899242e+01 1.5000000e-01]

# %%
s = sim_(el[:])

# %%
sns.heatmap(s)
# Out:
# <Axes: >
