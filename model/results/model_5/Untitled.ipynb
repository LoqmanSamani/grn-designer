# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
import seaborn as sns

# %%
data = h5py.File("data1.h5", "r")
print(data.keys())
# Out:
# <KeysViewHDF5 ['accuracy', 'cost', 'ind', 'target', 'time', 'y_hat']>

# %%
sns.heatmap(data["ind"][1, :, :], cmap="Blues", cbar_kws={'shrink':1, 'aspect': 10, 'pad': 0.01})
plt.axis("off")
# Out:
# (0.0, 100.0, 100.0, 0.0)
